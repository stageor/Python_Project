# %% [markdown]
# # Clean Colab Starter Notebook
#
# Minimal structure for reproducible Python work.
#
# Workflow:
# 1. Install dependencies
# 2. Import libraries
# 3. Load data
# 4. Process
# 5. Output

# %%
# Install dependencies (if needed)
# Uncomment if required
# !pip install pandas numpy

# %%
# Imports
import os
import sys
import numpy as np
import pandas as pd

print("Environment Ready")

# %%
# Check working directory
os.getcwd()

# %%
# Example: Load dataset
# Replace with actual file path

# df = pd.read_csv("data.csv")
# df.head()

# %%
# Basic sanity check template

# print(df.shape)
# print(df.info())
# print(df.describe())

# %% [markdown]
# ## Notes
#
# - Restart Runtime → Run All before finalizing.
# - Keep cells independent.
# - Avoid hidden state errors.
# - Use markdown to explain decisions.
